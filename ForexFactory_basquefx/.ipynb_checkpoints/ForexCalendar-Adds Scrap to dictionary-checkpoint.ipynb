# %%
import requests
from bs4 import BeautifulSoup
import pandas

page = requests.get("https://www.forexfactory.com/calendar.php?day=today")
content = page.content

soup = BeautifulSoup(content,"html.parser")

# %%
table = soup.find_all("tr",{"class":"calendar_row"})
#print(table)

forcal = []
for item in table:
    dict = {}
    
    dict["Currency"] = item.find_all("td", {"class":"calendar__currency"})[0].text #Currency
    dict["Event"] = item.find_all("td",{"class":"calendar__event"})[0].text.strip() #Event Name
    dict["Time_Eastern"] = item.find_all("td", {"class":"calendar__time"})[0].text #Time Eastern
    impact = item.find_all("td", {"class":"impact"})
    
    for icon in range(0,len(impact)):
        dict["Impact"] = impact[icon].find_all("span")[0]['title']

    dict["Actual"] = item.find_all("td", {"class":"calendar__actual"})[0].text #Actual Value
    dict["Forecast"] = item.find_all("td", {"class":"calendar__forecast"})[0].text #forecasted Value
    dict["Previous"] = item.find_all("td", {"class":"calendar__previous"})[0].text # Previous
    forcal.append(dict)

# %%
forcal
# Out:
# [{'Actual': '-15K',
#   'Currency': 'EUR',
#   'Event': 'German Unemployment Change',
#   'Forecast': '-10K',
#   'Impact': 'Medium Impact Expected',
#   'Previous': '-29K',
#   'Time_Eastern': '3:55am'},
#  {'Actual': '53.1',
#   'Currency': 'GBP',
#   'Event': 'Construction PMI',
#   'Forecast': '52.1',
#   'Impact': 'High Impact Expected',
#   'Previous': '52.2',
#   'Time_Eastern': '4:30am'},
#  {'Actual': '0.5%',
#   'Currency': 'EUR',
#   'Event': 'Prelim Flash GDP q/q',
#   'Forecast': '0.5%',
#   'Impact': 'Medium Impact Expected',
#   'Previous': '0.4%',
#   'Time_Eastern': '5:00am'},
#  {'Actual': '-0.3%',
#   'Currency': 'EUR',
#   'Event': 'PPI m/m',
#   'Forecast': '0.1%',
#   'Impact': 'Low Impact Expected',
#   'Previous': '0.0%',
#   'Time_Eastern': ''},
#  {'Actual': '0.33|1.5',
#   'Currency': 'EUR',
#   'Event': 'German 10-y Bond Auction',
#   'Forecast': '',
#   'Impact': 'Low Impact Expected',
#   'Previous': '0.21|1.4',
#   'Time_Eastern': '5:33am'},
#  {'Actual': '177K',
#   'Currency': 'USD',
#   'Event': 'ADP Non-Farm Employment Change',
#   'Forecast': '178K',
#   'Impact': 'High Impact Expected',
#   'Previous': '255K',
#   'Time_Eastern': '8:15am'},
#  {'Actual': '53.1',
#   'Currency': 'USD',
#   'Event': 'Final Services PMI',
#   'Forecast': '52.5',
#   'Impact': 'Low Impact Expected',
#   'Previous': '52.5',
#   'Time_Eastern': '9:45am'},
#  {'Actual': '57.5',
#   'Currency': 'USD',
#   'Event': 'ISM Non-Manufacturing PMI',
#   'Forecast': '56.1',
#   'Impact': 'High Impact Expected',
#   'Previous': '55.2',
#   'Time_Eastern': '10:00am'},
#  {'Actual': '-0.9M',
#   'Currency': 'USD',
#   'Event': 'Crude Oil Inventories',
#   'Forecast': '-3.3M',
#   'Impact': 'High Impact Expected',
#   'Previous': '-3.6M',
#   'Time_Eastern': '10:30am'},
#  {'Actual': '',
#   'Currency': 'USD',
#   'Event': 'FOMC Statement',
#   'Forecast': '',
#   'Impact': 'High Impact Expected',
#   'Previous': '',
#   'Time_Eastern': '2:00pm'},
#  {'Actual': '<1.00%',
#   'Currency': 'USD',
#   'Event': 'Federal Funds Rate',
#   'Forecast': '<1.00%',
#   'Impact': 'High Impact Expected',
#   'Previous': '<1.00%',
#   'Time_Eastern': ''},
#  {'Actual': '',
#   'Currency': 'JPY',
#   'Event': 'Bank Holiday',
#   'Forecast': '',
#   'Impact': 'Non-Economic',
#   'Previous': '',
#   'Time_Eastern': 'All Day'},
#  {'Actual': '',
#   'Currency': 'AUD',
#   'Event': 'HIA New Home Sales m/m',
#   'Forecast': '',
#   'Impact': 'Low Impact Expected',
#   'Previous': '0.2%',
#   'Time_Eastern': '\xa09:00pm'},
#  {'Actual': '',
#   'Currency': 'NZD',
#   'Event': 'ANZ Commodity Prices m/m',
#   'Forecast': '',
#   'Impact': 'Low Impact Expected',
#   'Previous': '0.4%',
#   'Time_Eastern': ''},
#  {'Actual': '',
#   'Currency': 'AUD',
#   'Event': 'Trade Balance',
#   'Forecast': '3.33B',
#   'Impact': 'High Impact Expected',
#   'Previous': '3.57B',
#   'Time_Eastern': '9:30pm'},
#  {'Actual': '',
#   'Currency': 'CNY',
#   'Event': 'Caixin Services PMI',
#   'Forecast': '52.6',
#   'Impact': 'Low Impact Expected',
#   'Previous': '52.2',
#   'Time_Eastern': '9:45pm'},
#  {'Actual': '',
#   'Currency': 'AUD',
#   'Event': 'RBA Gov Lowe Speaks',
#   'Forecast': '',
#   'Impact': 'High Impact Expected',
#   'Previous': '',
#   'Time_Eastern': '11:10pm'}]

# %%
df = pandas.DataFrame(forcal)

# %%
df
# Out:
#       Actual Currency                           Event Forecast  \
# 0       -15K      EUR      German Unemployment Change     -10K
# 1       53.1      GBP                Construction PMI     52.1
# 2       0.5%      EUR            Prelim Flash GDP q/q     0.5%
# 3      -0.3%      EUR                         PPI m/m     0.1%
# 4   0.33|1.5      EUR        German 10-y Bond Auction
# 5       177K      USD  ADP Non-Farm Employment Change     178K
# 6       53.1      USD              Final Services PMI     52.5
# 7       57.5      USD       ISM Non-Manufacturing PMI     56.1
# 8      -0.9M      USD           Crude Oil Inventories    -3.3M
# 9                 USD                  FOMC Statement
# 10    <1.00%      USD              Federal Funds Rate   <1.00%
# 11                JPY                    Bank Holiday
# 12                AUD          HIA New Home Sales m/m
# 13                NZD        ANZ Commodity Prices m/m
# 14                AUD                   Trade Balance    3.33B
# 15                CNY             Caixin Services PMI     52.6
# 16                AUD             RBA Gov Lowe Speaks
#
#                     Impact  Previous Time_Eastern
# 0   Medium Impact Expected      -29K       3:55am
# 1     High Impact Expected      52.2       4:30am
# 2   Medium Impact Expected      0.4%       5:00am
# 3      Low Impact Expected      0.0%
# 4      Low Impact Expected  0.21|1.4       5:33am
# 5     High Impact Expected      255K       8:15am
# 6      Low Impact Expected      52.5       9:45am
# 7     High Impact Expected      55.2      10:00am
# 8     High Impact Expected     -3.6M      10:30am
# 9     High Impact Expected                 2:00pm
# 10    High Impact Expected    <1.00%
# 11            Non-Economic                All Day
# 12     Low Impact Expected      0.2%       9:00pm
# 13     Low Impact Expected      0.4%
# 14    High Impact Expected     3.57B       9:30pm
# 15     Low Impact Expected      52.2       9:45pm
# 16    High Impact Expected                11:10pm
