# %%
import requests
from bs4 import BeautifulSoup
import pandas

page = requests.get("https://www.forexfactory.com/calendar.php?day=today")
content = page.content

soup = BeautifulSoup(content,"html.parser")

# %%
table = soup.find_all("tr",{"class":"calendar_row"})
#print(table)

forcal = []
for item in table:
    dict = {}
    
    dict["Currency"] = item.find_all("td", {"class":"calendar__currency"})[0].text #Currency
    dict["Event"] = item.find_all("td",{"class":"calendar__event"})[0].text.strip() #Event Name
    dict["Time_Eastern"] = item.find_all("td", {"class":"calendar__time"})[0].text #Time Eastern
    impact = item.find_all("td", {"class":"impact"})
    
    for icon in range(0,len(impact)):
        dict["Impact"] = impact[icon].find_all("span")[0]['title'].split(' ', 1)[0]

    dict["Actual"] = item.find_all("td", {"class":"calendar__actual"})[0].text #Actual Value
    dict["Forecast"] = item.find_all("td", {"class":"calendar__forecast"})[0].text #forecasted Value
    dict["Previous"] = item.find_all("td", {"class":"calendar__previous"})[0].text # Previous
    forcal.append(dict)

# %%
forcal
# Out:
# [{'Actual': '-15K',
#   'Currency': 'EUR',
#   'Event': 'German Unemployment Change',
#   'Forecast': '-10K',
#   'Impact': 'Medium',
#   'Previous': '-29K',
#   'Time_Eastern': '3:55am'},
#  {'Actual': '53.1',
#   'Currency': 'GBP',
#   'Event': 'Construction PMI',
#   'Forecast': '52.1',
#   'Impact': 'High',
#   'Previous': '52.2',
#   'Time_Eastern': '4:30am'},
#  {'Actual': '0.5%',
#   'Currency': 'EUR',
#   'Event': 'Prelim Flash GDP q/q',
#   'Forecast': '0.5%',
#   'Impact': 'Medium',
#   'Previous': '0.4%',
#   'Time_Eastern': '5:00am'},
#  {'Actual': '-0.3%',
#   'Currency': 'EUR',
#   'Event': 'PPI m/m',
#   'Forecast': '0.1%',
#   'Impact': 'Low',
#   'Previous': '0.0%',
#   'Time_Eastern': ''},
#  {'Actual': '0.33|1.5',
#   'Currency': 'EUR',
#   'Event': 'German 10-y Bond Auction',
#   'Forecast': '',
#   'Impact': 'Low',
#   'Previous': '0.21|1.4',
#   'Time_Eastern': '5:33am'},
#  {'Actual': '177K',
#   'Currency': 'USD',
#   'Event': 'ADP Non-Farm Employment Change',
#   'Forecast': '178K',
#   'Impact': 'High',
#   'Previous': '255K',
#   'Time_Eastern': '8:15am'},
#  {'Actual': '53.1',
#   'Currency': 'USD',
#   'Event': 'Final Services PMI',
#   'Forecast': '52.5',
#   'Impact': 'Low',
#   'Previous': '52.5',
#   'Time_Eastern': '9:45am'},
#  {'Actual': '57.5',
#   'Currency': 'USD',
#   'Event': 'ISM Non-Manufacturing PMI',
#   'Forecast': '56.1',
#   'Impact': 'High',
#   'Previous': '55.2',
#   'Time_Eastern': '10:00am'},
#  {'Actual': '-0.9M',
#   'Currency': 'USD',
#   'Event': 'Crude Oil Inventories',
#   'Forecast': '-3.3M',
#   'Impact': 'High',
#   'Previous': '-3.6M',
#   'Time_Eastern': '10:30am'},
#  {'Actual': '',
#   'Currency': 'USD',
#   'Event': 'FOMC Statement',
#   'Forecast': '',
#   'Impact': 'High',
#   'Previous': '',
#   'Time_Eastern': '2:00pm'},
#  {'Actual': '<1.00%',
#   'Currency': 'USD',
#   'Event': 'Federal Funds Rate',
#   'Forecast': '<1.00%',
#   'Impact': 'High',
#   'Previous': '<1.00%',
#   'Time_Eastern': ''},
#  {'Actual': '',
#   'Currency': 'JPY',
#   'Event': 'Bank Holiday',
#   'Forecast': '',
#   'Impact': 'Non-Economic',
#   'Previous': '',
#   'Time_Eastern': 'All Day'},
#  {'Actual': '',
#   'Currency': 'AUD',
#   'Event': 'HIA New Home Sales m/m',
#   'Forecast': '',
#   'Impact': 'Low',
#   'Previous': '0.2%',
#   'Time_Eastern': '\xa09:00pm'},
#  {'Actual': '',
#   'Currency': 'NZD',
#   'Event': 'ANZ Commodity Prices m/m',
#   'Forecast': '',
#   'Impact': 'Low',
#   'Previous': '0.4%',
#   'Time_Eastern': ''},
#  {'Actual': '',
#   'Currency': 'AUD',
#   'Event': 'Trade Balance',
#   'Forecast': '3.33B',
#   'Impact': 'High',
#   'Previous': '3.57B',
#   'Time_Eastern': '9:30pm'},
#  {'Actual': '',
#   'Currency': 'CNY',
#   'Event': 'Caixin Services PMI',
#   'Forecast': '52.6',
#   'Impact': 'Low',
#   'Previous': '52.2',
#   'Time_Eastern': '9:45pm'},
#  {'Actual': '',
#   'Currency': 'AUD',
#   'Event': 'RBA Gov Lowe Speaks',
#   'Forecast': '',
#   'Impact': 'High',
#   'Previous': '',
#   'Time_Eastern': '11:10pm'}]

# %%
df = pandas.DataFrame(forcal)

df[["Currency","Event", "Impact","Time_Eastern", "Actual","Forecast", "Previous"]]
# Out:
#    Currency                           Event        Impact Time_Eastern  \
# 0       EUR      German Unemployment Change        Medium       3:55am
# 1       GBP                Construction PMI          High       4:30am
# 2       EUR            Prelim Flash GDP q/q        Medium       5:00am
# 3       EUR                         PPI m/m           Low
# 4       EUR        German 10-y Bond Auction           Low       5:33am
# 5       USD  ADP Non-Farm Employment Change          High       8:15am
# 6       USD              Final Services PMI           Low       9:45am
# 7       USD       ISM Non-Manufacturing PMI          High      10:00am
# 8       USD           Crude Oil Inventories          High      10:30am
# 9       USD                  FOMC Statement          High       2:00pm
# 10      USD              Federal Funds Rate          High
# 11      JPY                    Bank Holiday  Non-Economic      All Day
# 12      AUD          HIA New Home Sales m/m           Low       9:00pm
# 13      NZD        ANZ Commodity Prices m/m           Low
# 14      AUD                   Trade Balance          High       9:30pm
# 15      CNY             Caixin Services PMI           Low       9:45pm
# 16      AUD             RBA Gov Lowe Speaks          High      11:10pm
#
#       Actual Forecast  Previous
# 0       -15K     -10K      -29K
# 1       53.1     52.1      52.2
# 2       0.5%     0.5%      0.4%
# 3      -0.3%     0.1%      0.0%
# 4   0.33|1.5           0.21|1.4
# 5       177K     178K      255K
# 6       53.1     52.5      52.5
# 7       57.5     56.1      55.2
# 8      -0.9M    -3.3M     -3.6M
# 9
# 10    <1.00%   <1.00%    <1.00%
# 11
# 12                         0.2%
# 13                         0.4%
# 14              3.33B     3.57B
# 15               52.6      52.2
# 16

# %%
df.to_html("forexcal.html")
